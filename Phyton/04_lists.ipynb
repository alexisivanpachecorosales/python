# %%
### Lists ###
#Definicion

my_list=list()
my_other_list=[] #

print(len(my_list))
my_list= [35,24,62,52,30,30,17]

print(my_list)
print(len(my_list))

my_other_list=[35,1.77, "Ivonne" ,"Alexandra"]
print (type(my_list))
print (type(my_other_list))


#Acceso a elememtos y búsqueda

print(my_other_list[0])
print(my_other_list[1])
print(my_other_list[-1])
print(my_other_list[-4])
print(my_list.count(30))
#print(my_other_list[4])  Index Error
#print(my_other_list[-5])  Index Error

print(my_other_list.index("Ivonne"))

age, height, name, surname, = my_other_list
print(name)

age, height, age, surname= my_other_list[2], my_other_list[1], my_other_list[0], my_other_list[3],
print(age)

#Concatenanción
print(my_list + my_other_list)
#print(my_list - my_other_list)

#Creacion, insercion,actualización y eliminación

my_other_list.append("CECYTEM")
print(my_other_list)

my_other_list.insert(1, "Rojo") #Se pasa al lugar 1 []=[35, ['Rojo'], 1.77, 'Ivonne', 'Alexandra', 'CECYTEM']
print(my_other_list)

my_other_list[1]="Azul" #Se pasa al lugar 1 quitando el "Rojo"=[35, 'Azul', 1.77, 'Ivonne', 'Alexandra', 'CECYTEM']
print(my_other_list)

my_other_list.remove("Azul")
print(my_other_list)

my_list.remove(30)
print (my_list)

print(my_list.pop())
print(my_list)

my_pop_elemnt=my_list.pop(2)
print(my_pop_elemnt)
print(my_list)

del my_list[2]
print(my_list)

#Operacion con listas

my_new_list =my_list.copy()

my_list.clear()
print(my_list)
print(my_new_list)

my_new_list.reverse()
print(my_new_list)

my_new_list.sort() #Para ordenar
print(my_new_list)

#Sublistas

print(my_new_list[1:3])

#Cambio de tipo
my_list ="Hola Python"
print(my_list)
print(type(my_list))
# Out:
# 0
# [35, 24, 62, 52, 30, 30, 17]
# 7
# <class 'list'>
# <class 'list'>
# 35
# 1.77
# Alexandra
# 35
# 2
# 2
# Ivonne
# 35
# [35, 24, 62, 52, 30, 30, 17, 35, 1.77, 'Ivonne', 'Alexandra']
# [35, 1.77, 'Ivonne', 'Alexandra', 'CECYTEM']
# [35, 'Rojo', 1.77, 'Ivonne', 'Alexandra', 'CECYTEM']
# [35, 'Azul', 1.77, 'Ivonne', 'Alexandra', 'CECYTEM']
# [35, 1.77, 'Ivonne', 'Alexandra', 'CECYTEM']
# [35, 24, 62, 52, 30, 17]
# 17
# [35, 24, 62, 52, 30]
# 62
# [35, 24, 52, 30]
# [35, 24, 30]
# []
# [35, 24, 30]
# [30, 24, 35]
# [24, 30, 35]
