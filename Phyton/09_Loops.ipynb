# %%
###Loops ### ###Ciclos###


#While

my_condition=0

while my_condition< 10:
  print(my_condition)
  my_condition +=2
else: #Es opcional
  print("Mi condición es mayor o igual que 10")

  print("La ejecución continúa")

while my_condition < 20:
   my_condition +=1
   if my_condition ==15:
       print("Se detiene la ejecución")
       break
   print(my_condition)

print("La ejecución continúa")


#For

my_list =[35,24,62,52,30,17]

for element in my_list:
  print(element)

my_tuple =(16,1.60, "Ivonne","Alexandra","Rodriguez","Juarez")

for element in my_tuple:
  print(element)


my_set ={"Ivonne","Rodriguez",16}

for element in my_set:
   print(element)

my_dict={"Nombre":"Ivonne", "Apellido": "Rodriguez", "Edad": 16, 1: "Python"}

for element in my_dict:
   print(element)
   if element =="Edad":
    break
else:
  print("El bluce for para diccionario finalizado")

print("La ejecucion continua")

for element in my_dict:
   print(element)
   if element =="Edad":
    continue
    print("Se ejecuta")
else:
  print("El bluce for para diccionario finalizado")
# Out:
# 0
# 2
# 4
# 6
# 8
# Mi condición es mayor o igual que 10
# La ejecución continúa
# 11
# 12
# 13
# 14
# Se detiene la ejecución
# La ejecución continúa
# 35
# 24
# 62
# 52
# 30
# 17
# 16
# 1.6
# Ivonne
# Alexandra
# Rodriguez
# Juarez
# Ivonne
# 16
# Rodriguez
# Nombre
# Apellido
# Edad
# La ejecucion continua
# Nombre
# Apellido
# Edad
# 1
# El bluce for para diccionario finalizado
